# %%
#pip install pandas

# %%
import pandas as pd

# %%
#pip install numpy

# %%
import numpy as np

# %%
data = pd.read_csv(r"./insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#pip install seaborn

# %%
#pip install matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.replace({'sex':{'male':0, 'female':1}}, inplace = True)
data.replace({'smoker':{'yes':0,'no':1}}, inplace = True)
data.replace({'region':{'southeast':0, 'southwest':1, 'northeast': 2, 'northwest':3}}, inplace = True)
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       0       1  16884.92400
# 1   18    0  33.770         1       1       0   1725.55230
# 2   28    0  33.000         3       1       0   4449.46200
# 3   33    0  22.705         0       1       3  21984.47061
# 4   32    0  28.880         0       1       3   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.columns.values
# Out:
# array(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'],
#       dtype=object)

# %%
data.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
sns.heatmap(data.isnull(), cbar = False, yticklabels = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data[['age','sex','bmi','smoker','region','children','charges']],diag_kind='kde')

# %%
plt.figure(figsize=(7,9))
sns.scatterplot(x = 'age',y= 'charges', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
plt.figure(figsize=(4,9))
sns.scatterplot(x = 'sex',y= 'charges', data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
plt.figure(figsize=(7,14))
sns.scatterplot(x = 'bmi',y= 'charges', data=data)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize=(7,9))
sns.scatterplot(x = 'children',y= 'charges', data=data)
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
plt.figure(figsize=(3,9))
sns.scatterplot(x = 'smoker',y= 'charges', data=data)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize=(7,9))
sns.scatterplot(x = 'region',y= 'charges', data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.age,color='green')
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.sex,color='green')
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.bmi,color='green')
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.children,color='green')
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.smoker,color='green')
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.region,color='green')
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
sns.set_style('whitegrid')
sns.boxplot(x=data.charges,color='green')
plt.tight_layout()

# %%
data.columns.values
# Out:
# array(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'],
#       dtype=object)

# %%
l = data.columns.values
#l = np.delete(l,5)
#l = np.delete(l,4)
#l = np.delete(l,1)
number_of_columns = 7
number_of_rows = 9
print(l)
print(number_of_rows)
plt.figure(figsize=(4*number_of_columns,7*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(data[l[i]])
# Out:
# ['age' 'sex' 'bmi' 'children' 'smoker' 'region' 'charges']
# 9
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(data.shape)
q1 = data["age"].quantile(0.10)
q3 = data["age"].quantile(0.90)
iqr = q3 - q1
lower = np.where(data["age"]<=(q1-1.5*iqr))
upper = np.where(data["age"]>=(q3 + 1.5 * iqr))
print(np.where(data["age"]>=(q3 + 1.5 * iqr)))
print(np.where(data["age"]<=(q1-1.5*iqr)))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
print(data.shape)
# Out:
# (1338, 7)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (1338, 7)

# %%
print(data.shape)
q1 = data["children"].quantile(0.05)
q3 = data["children"].quantile(0.95)
iqr = q3 - q1
#lower = data["children"]<=(q1-1.5*iqr)
#upper = data["children"]>=(q3 + 1.5 * iqr)
lower = np.where(data["children"]<=(q1-1.5*iqr))
upper = np.where(data["children"]>=(q3 + 1.5 * iqr))
#print(q1 , ' ' ,q3)
#print(np.where(data["children"]>=(q3 + 1.5 * iqr)))
#print(np.where(data["children"]<=(q1-1.5*iqr)))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
print(data.shape)
# Out:
# (1338, 7)
# (1338, 7)

# %%
print(data.shape)
q1 = data["sex"].quantile(0.05)
q3 = data["sex"].quantile(0.95)
iqr = q3 - q1
lower = np.where(data["sex"]<=(q1-1.5*iqr))
upper = np.where(data["sex"]>=(q3 + 1.5 * iqr))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
print(data.shape)
# Out:
# (1338, 7)
# (1338, 7)

# %%
print(data.shape)
q1 = data["bmi"].quantile(0.20)
q3 = data["bmi"].quantile(0.80)
iqr = q3 - q1
lower = np.where(data["bmi"]<=(q1-1.5*iqr))
upper = np.where(data["bmi"]>=(q3 + 1.5 * iqr))
print(np.where(data["bmi"]>=(q3 + 1.5 * iqr)))
print(np.where(data["bmi"]<=(q1-1.5*iqr)))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
print(data.shape)
# Out:
# (1338, 7)
# (array([1047, 1317], dtype=int64),)
# (array([], dtype=int64),)
# (1336, 7)

# %%
print(data.shape)
q1 = data["smoker"].quantile(0.10)
q3 = data["smoker"].quantile(0.90)
iqr = q3 - q1
lower = np.where(data["smoker"]<=(q1-1.5*iqr))
upper = np.where(data["smoker"]>=(q3 + 1.5 * iqr))
print(np.where(data["smoker"]>=(q3 + 1.5 * iqr)))
print(np.where(data["smoker"]<=(q1-1.5*iqr)))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
print(data.shape)
# Out:
# (1336, 7)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (1336, 7)

# %%
print(data.shape)
q1 = data["charges"].quantile(0.20)
q3 = data["charges"].quantile(0.80)
iqr = q3 - q1
lower = np.where(data["charges"]<=(q1-1.5*iqr))
upper = np.where(data["charges"]>=(q3 + 1.5 * iqr))
print(np.where(data["charges"]>=(q3 + 1.5 * iqr)))
print(np.where(data["charges"]<=(q1-1.5*iqr)))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
print(data.shape)
# Out:
# (1336, 7)
# (array([  34,   39,   55,   94,  109,  175,  251,  265,  281,  288,  328,
#         330,  420,  421,  488,  530,  543,  549,  569,  577,  668,  674,
#         677,  819,  845,  860,  883,  901,  951, 1061, 1095, 1121, 1145,
#        1229, 1239, 1240, 1283, 1299, 1300], dtype=int64),)
# (array([], dtype=int64),)
# (1297, 7)

# %%
n=7
cols = data.corr().nlargest(n, 'charges')['charges'].index
cm = data[cols].corr()
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
#pip install scikit-learn

# %%
X = data.drop('charges',axis=1)
y = data['charges']
print(X)
print(y)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       3
# 4      32    0  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       3
# 1334   18    1  31.920         0       1       2
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       3
#
# [1297 rows x 6 columns]
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1297, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1037, 6)
# (260, 6)
# (1037,)
# (260,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[0.02173913 1.         0.07669959 0.         1.         0.33333333]
#  [0.41304348 0.         0.35052295 0.4        1.         1.        ]
#  [0.7173913  1.         0.52701917 0.         1.         0.        ]
#  ...
#  [0.08695652 1.         0.69276583 0.         1.         0.66666667]
#  [0.80434783 1.         0.6141778  0.         1.         0.33333333]
#  [1.         1.         0.31740267 0.         0.         1.        ]]

# %%
print(X_test)
# Out:
# [[0.7173913  0.         0.58134805 0.2        1.         0.        ]
#  [0.58695652 0.         0.22080186 0.4        1.         0.66666667]
#  [0.2173913  0.         0.22777455 0.4        1.         0.33333333]
#  ...
#  [0.04347826 1.         0.24578733 0.         0.         0.        ]
#  [0.47826087 0.         0.26496223 0.         1.         0.        ]
#  [0.86956522 1.         0.49404416 0.         1.         0.66666667]]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)
print(y_train_pred)
print(y_train)
# Out:
# [ -629.48971207  8085.0115112  11286.10629318 ...  6642.42976082
#  13375.3988414  35193.32837665]
# 1129     1728.89700
# 24       6203.90175
# 605      9283.56200
# 1238     6985.50695
# 908     15170.06900
#            ...
# 595      8823.98575
# 1002     1972.95000
# 78       2755.02095
# 619     10713.64400
# 890     29330.98315
# Name: charges, Length: 1037, dtype: float64

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
####print("R^2: ", r2_score(y_train_pred, y_train))
print("mean_absolute_error: ", mean_absolute_error(y_train_pred, y_train))
####print("mean_squared_error: ", mean_squared_error(y_train_pred, y_train))
print("mean_absolute_percentage_error: ", mean_absolute_percentage_error(y_train_pred, y_train))
print("root_mean_squared_error: ", np.sqrt(mean_squared_error(y_train_pred, y_train)))
# Out:
# mean_absolute_error:  4014.969688895504
# mean_absolute_percentage_error:  0.6426668279923948
# root_mean_squared_error:  5769.449092167789

# %%
y_test_pred = model.predict(X_test)

# %%
####print("R^2: ", r2_score(y_test_pred, y_test))
print("mean_absolute_error: ", mean_absolute_error(y_test_pred, y_test))
####print("mean_squared_error: ", mean_squared_error(y_test_pred, y_test))
print("mean_absolute_percentage_error: ", mean_absolute_percentage_error(y_test_pred, y_test))
print("root_mean_squared_error: ", np.sqrt(mean_squared_error(y_test_pred, y_test)))
# Out:
# mean_absolute_error:  3862.9905344470308
# mean_absolute_percentage_error:  0.38715773409648935
# root_mean_squared_error:  5778.536568953723

# %%
X.columns.values
# Out:
# array(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype=object)

# %%
output_data = [[20, 0, 27.55, 0, 1, 1]]
output_data = scaler.transform(output_data)
print(output_data)
pred_cost = model.predict(output_data)
print(pred_cost)
# Out:
# [[0.04347826 0.         0.33672284 0.         1.         0.33333333]]
# [2320.1827703]
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
import joblib
joblib.dump(model,'Linear_model')
# Out:
# ['Linear_model']
